# %%
from pxtextmining.pipelines.text_classification_pipeline import text_classification_pipeline

pipe, tuning_results, pred, accuracy_per_class, p_compare_models_bar, index_train, index_test = \
    text_classification_pipeline(filename='../datasets/text_data.csv', target="criticality", predictor="feedback",
                                 test_size=0.33,
                                 ordinal=True,
                                 tknz="spacy",
                                 metric="class_balance_accuracy",
                                 cv=2, n_iter=1, n_jobs=5, verbose=3,
                                 learners=[
                                     "SGDClassifier",
                                     # "RidgeClassifier",
                                     # "Perceptron",
                                     # "PassiveAggressiveClassifier",
                                     # "BernoulliNB",
                                     # "ComplementNB",
                                     # "MultinomialNB",
                                     # "KNeighborsClassifier",
                                     # "NearestCentroid",
                                     # "RandomForestClassifier"
                                     ],
                                 objects_to_save=[
                                     "pipeline",
                                     "tuning results",
                                     "predictions",
                                     "accuracy per class",
                                     "index - training data",
                                     "index - test data",
                                     "bar plot"
                                 ],
                                 save_objects_to_server=False,
                                 save_objects_to_disk=True,
                                 save_pipeline_as="pipeline_criticality_issue_26",
                                 results_folder_name="results_criticality_issue_26",
                                 reduce_criticality=True,
                                 theme="label")
# Out:
# Loading dataset...
# Preparing training and test sets...
# Done
# Stripping punctuation from text...
# Stripping excess spaces, whitespaces and line breaks from text...
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# /home/yiwen-h/.pyenv/versions/3.8.12/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /home/yiwen-h/.pyenv/versions/3.8.12/lib/python3.8/site-packages/pxtextmining/factories/factory_data_load_and_split.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['theme'] = text_data['theme'].copy()
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   2 out of   2 | elapsed:    8.7s remaining:    0.0s
# [Parallel(n_jobs=5)]: Done   2 out of   2 | elapsed:    8.7s finished
# /home/yiwen-h/.pyenv/versions/3.8.12/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:484: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# /home/yiwen-h/.pyenv/versions/3.8.12/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:484: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# The best estimator is SGDClassifier(class_weight='balanced', loss='log', max_iter=10000,
#               penalty='elasticnet')
# The best parameters are:
# sampling__kw_args: {'up_balancing_counts': 300}
# clf__estimator__penalty: elasticnet
# clf__estimator__max_iter: 10000
# clf__estimator__loss: log
# clf__estimator__class_weight: balanced
# clf__estimator: SGDClassifier(class_weight='balanced', loss='log', max_iter=10000,
#               penalty='elasticnet')
# alltrans__theme__scaler: OneHotEncoder(categories=[["Couldn't be improved", 'Access', 'Care received',
#                            'Communication', 'Dignity',
#                            'Environment/ facilities', 'Miscellaneous', 'Staff',
#                            'Transition/coordination']])
# alltrans__process__preprocessor__texttr__text__transformer__use_idf: False
# alltrans__process__preprocessor__texttr__text__transformer__tokenizer: <pxtextmining.helpers.tokenization.LemmaTokenizer object at 0x7f8053a8d6d0>
# alltrans__process__preprocessor__texttr__text__transformer__preprocessor: <function text_preprocessor at 0x7f80a37684c0>
# alltrans__process__preprocessor__texttr__text__transformer__norm: None
# alltrans__process__preprocessor__texttr__text__transformer__ngram_range: (3, 3)
# alltrans__process__preprocessor__texttr__text__transformer__min_df: 3
# alltrans__process__preprocessor__texttr__text__transformer__max_df: 0.7
# alltrans__process__preprocessor__texttr__text__transformer: TfidfVectorizer(max_df=0.7, min_df=3, ngram_range=(3, 3), norm=None,
#                 preprocessor=<function text_preprocessor at 0x7f80a37684c0>,
#                 tokenizer=<pxtextmining.helpers.tokenization.LemmaTokenizer object at 0x7f8053a8d6d0>,
#                 use_idf=False)
# alltrans__process__preprocessor__sentimenttr__scaler__scaler__n_bins: 8
# alltrans__process__preprocessor__sentimenttr__scaler__scaler: KBinsDiscretizer(n_bins=8, strategy='kmeans')
# alltrans__process__preprocessor__lengthtr__scaler__scaler: KBinsDiscretizer(n_bins=3, strategy='kmeans')
# alltrans__process__featsel__selector__score_func: <function chi2 at 0x7f80a374a8b0>
# alltrans__process__featsel__selector__percentile: 100
# alltrans__process__featsel__selector: SelectPercentile(percentile=100, score_func=<function chi2 at 0x7f80a374a8b0>)
# The best score from the cross-validation for
#  the supplied scorer (Class Balance Accuracy) is 0.26
# Model accuracy on the test set is 49 percent
# Balanced accuracy on the test set is 40 percent
# Class balance accuracy on the test set is 33 percent
# Matthews correlation on the test set is 0.38
# Plotting performance of the best of each estimator...
# Fitting optimal pipeline on whole dataset...
# /home/yiwen-h/.pyenv/versions/3.8.12/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:484: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# Writing to disk...

# %%
import pandas as pd

test_data = pd.read_csv('../datasets/text_data.csv')
test_data.head()
# Out:
#   code                    label                    subcategory  \
# 0   xn     Couldn't be improved             Nothing to improve
# 1   ee  Environment/ facilities        Environment/ facilities
# 2   ap                   Access          Provision of services
# 3   mi            Communication  Amount/clarity of information
# 4   mm            Communication                  Communication
#
#                                             feedback criticality organization  \
# 0                                           Nothing.           3      Trust A
# 1               Temperature in theatre a little low.          -1      Trust A
# 2   Same service available at Bingham Health Centre.          -2      Trust A
# 3  Appointment details given over phone - no phys...          -1      Trust A
# 4  On one occasion I was not made aware that my a...          -3      Trust A
#
#        question  row_index
# 0  Trust A - Q1          0
# 1  Trust A - Q1          1
# 2  Trust A - Q1          2
# 3  Trust A - Q1          3
# 4  Trust A - Q1          4

# %%
test_data.shape
# Out:
# (10334, 8)

# %%
pipe, tuning_results, pred, accuracy_per_class, p_compare_models_bar, index_train, index_test

# %%
pipe
# Out:
# RandomizedSearchCV(cv=2,
#                    estimator=Pipeline(steps=[('sampling',
#                                               FunctionSampler(func=<function random_over_sampler_data_generator at 0x7f809e84d1f0>,
#                                                               kw_args={'random_state': 0,
#                                                                        'threshold': 200,
#                                                                        'up_balancing_counts': 300},
#                                                               validate=False)),
#                                              ('alltrans',
#                                               ColumnTransformer(transformers=[('theme',
#                                                                                ScalerSwitcher(),
#                                                                                ['theme']),
#                                                                               ('process',
#                                                                                Pipeline(steps=[('preprocess...
#                                          'sampling__kw_args': [{'up_balancing_counts': 300},
#                                                                {'up_balancing_counts': 800}]}],
#                    refit='Class Balance Accuracy',
#                    scoring={'Accuracy': make_scorer(accuracy_score),
#                             'Balanced Accuracy': make_scorer(balanced_accuracy_score),
#                             'Class Balance Accuracy': make_scorer(class_balance_accuracy_score),
#                             'Matthews Correlation Coefficient': make_scorer(matthews_corrcoef)},
#                    verbose=3)

# %%
tuning_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       4.040422      0.266007          2.40902         0.03005
#
#         param_sampling__kw_args param_clf__estimator__penalty  \
# 0  {'up_balancing_counts': 300}                    elasticnet
#
#   param_clf__estimator__max_iter param_clf__estimator__loss  \
# 0                          10000                        log
#
#   param_clf__estimator__class_weight  \
# 0                           balanced
#
#                                 param_clf__estimator  ...  \
# 0  SGDClassifier(class_weight='balanced', loss='l...  ...
#
#   split1_test_Matthews Correlation Coefficient  \
# 0                                     0.336423
#
#   mean_test_Matthews Correlation Coefficient  \
# 0                                   0.331183
#
#   std_test_Matthews Correlation Coefficient  \
# 0                                  0.005239
#
#   rank_test_Matthews Correlation Coefficient  \
# 0                                          1
#
#   split0_test_Class Balance Accuracy split1_test_Class Balance Accuracy  \
# 0                           0.256706                           0.267007
#
#   mean_test_Class Balance Accuracy std_test_Class Balance Accuracy  \
# 0                         0.261857                        0.005151
#
#   rank_test_Class Balance Accuracy   learner
# 0                                1  Logistic
#
# [1 rows x 47 columns]

# %%
pred
# Out:
#      criticality_pred  row_index
# 0                  -3        685
# 1                   3        288
# 2                   2       8419
# 3                   2       3267
# 4                   1       5404
# ...               ...        ...
# 3394               -2       1463
# 3395                0        983
# 3396                3       9430
# 3397                3       4475
# 3398                2        982
#
# [3399 rows x 2 columns]

# %%
accuracy_per_class
# Out:
#   class  counts  accuracy
# 0    -1      76  0.171053
# 1    -2     202  0.336634
# 2    -3     260  0.388462
# 3    -4      64  0.515625
# 4     0     847  0.604486
# 5     1      93  0.247312
# 6     2     348  0.465517
# 7     3    1218  0.541051
# 8     4     291  0.353952

# %%
p_compare_models_bar
# Out:
# <AxesSubplot:title={'center':'Learner performance ordered by Class Balance Accuracy'}>

# %%
index_train
# Out:
#       row_index
# 0          1155
# 1          7233
# 2          8108
# 3          4502
# 4           192
# ...         ...
# 6893       4235
# 6894       4889
# 6895       5134
# 6896       4682
# 6897       1723
#
# [6898 rows x 1 columns]

# %%
index_test
# Out:
#       row_index
# 0           685
# 1           288
# 2          8419
# 3          3267
# 4          5404
# ...         ...
# 3394       1463
# 3395        983
# 3396       9430
# 3397       4475
# 3398        982
#
# [3399 rows x 1 columns]
